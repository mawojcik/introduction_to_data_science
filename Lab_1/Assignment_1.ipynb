# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
#  ## Exercise 1
# a) Load house sales data from file kc_house_data.csv, print first records.
# b) Print the variable list. Select categorical and numerical variables.
# c) Compute basic statistics of numerical variables. Are all of them meaningful?

# %%
from pandas import read_csv

#a)
#Your code:
df = read_csv("kc_house_data.csv")
df.head(3)
#Hint: read_csv(), head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# [3 rows x 21 columns]

# %%
#b) 
variable_list = df.head(0)
variable_list   #print variables list

house_categorical_df = df.select_dtypes(include=['object'])
house_numerical_df = df.select_dtypes(include=['int', 'float'])
# df.dtypes
house_numerical_df
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0         1.0           0     0          3      7        1180              0
# 1         2.0           0     0          3      7        2170            400
# 2         1.0           0     0          3      6         770              0
# 3         1.0           0     0          5      7        1050            910
# 4         1.0           0     0          3      8        1680              0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21608     3.0           0     0          3      8        1530              0
# 21609     2.0           0     0          3      8        2310              0
# 21610     2.0           0     0          3      7        1020              0
# 21611     2.0           0     0          3      8        1600              0
# 21612     2.0           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1955             0    98178  47.5112 -122.257           1340
# 1          1951          1991    98125  47.7210 -122.319           1690
# 2          1933             0    98028  47.7379 -122.233           2720
# 3          1965             0    98136  47.5208 -122.393           1360
# 4          1987             0    98074  47.6168 -122.045           1800
# ...         ...           ...      ...      ...      ...            ...
# 21608      2009             0    98103  47.6993 -122.346           1530
# 21609      2014             0    98146  47.5107 -122.362           1830
# 21610      2009             0    98144  47.5944 -122.299           1020
# 21611      2004             0    98027  47.5345 -122.069           1410
# 21612      2008             0    98144  47.5941 -122.299           1020
#
#        sqft_lot15
# 0            5650
# 1            7639
# 2            8062
# 3            5000
# 4            7503
# ...           ...
# 21608        1509
# 21609        7200
# 21610        2007
# 21611        1287
# 21612        1357
#
# [21613 rows x 20 columns]

# %%
#c)
#Your code:
df.describe()

#count - number of not empty values
    #returns the same nuber everywhere, because we have no empty cells
#mean - the average (mean) value
    # for example, the average number of bedrooms is 3
#std - standard deviation
#min - minimum value
    # for example, the smallest square foot living is 290
#percentiles - gow many of the values are less than the given percentile
#max - maximum value
    # for example, maximum number of bedrooms is 33

#Hint: Function describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# ## Exercise 2
# Using scatter plot:
# a) Show the relation of square footage and price.
# b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
# c) Check how good apartments are distributed over the city. First, plot zipcode versus price. Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.

# %%
#a)
#Your code:
plt.scatter(df['sqft_living'], df['price'])
plt.xlabel("living square foot")
plt.ylabel("price")

#Hint plt.scatter
# Out:
# Text(0, 0.5, 'price')

# %%
#b) b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
#Your code:

plt.scatter(df['grade'], df['price'])
plt.xlabel("grade")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
#c) Check how good apartments are distributed over the city. First, plot zipcode versus price.

#Your code:
plt.scatter(df['zipcode'], df['price'])
plt.xlabel("zipcode")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
# Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.
#Your code:

plt.scatter(df['long'], df['lat'], c=df['grade'])
plt.xlabel("longitude")
plt.ylabel("lattitude")
# Out:
# Text(0, 0.5, 'lattitude')

# %% [markdown]
# ## Exercise 3
# a) Create boxplot of apartment's grade versus it's price. Compare with plot 2b).
# b) Create mosaic plot of any two categorical variables.

# %%
#a)
#Your code:
unique_grades = df['grade'].unique()
# unique_grades = sorted(unique_grades)

# df['price']

# unique_grades[2].append(df['price'])
grades = [[] for _ in range(13)]

for i in range(1, 14):
    prices = []
    for j in range(len(df['grade'])):
        if df['grade'].iloc[j] == i:
            prices.append(df['price'].iloc[j])
    grades[i-1] = prices
plt.boxplot(grades)
# plt.xlabel("grade")
# plt.ylabel("price")
#Hint: plt.boxplot
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2935c31f0>,
#   <matplotlib.lines.Line2D at 0x2935c3490>,
#   <matplotlib.lines.Line2D at 0x2935f4370>,
#   <matplotlib.lines.Line2D at 0x2935f4610>,
#   <matplotlib.lines.Line2D at 0x2934a1e70>,
#   <matplotlib.lines.Line2D at 0x29346fca0>,
#   <matplotlib.lines.Line2D at 0x2935f6170>,
#   <matplotlib.lines.Line2D at 0x2935f6410>,
#   <matplotlib.lines.Line2D at 0x2935f73d0>,
#   <matplotlib.lines.Line2D at 0x2935f7670>,
#   <matplotlib.lines.Line2D at 0x293634670>,
#   <matplotlib.lines.Line2D at 0x293634910>,
#   <matplotlib.lines.Line2D at 0x2936358d0>,
#   <matplotlib.lines.Line2D at 0x293635b70>,
#   <matplotlib.lines.Line2D at 0x293636b30>,
#   <matplotlib.lines.Line2D at 0x293636dd0>,
#   <matplotlib.lines.Line2D at 0x293637d90>,
#   <matplotlib.lines.Line2D at 0x29366c070>,
#   <matplotlib.lines.Line2D at 0x29366d030>,
#   <matplotlib.lines.Line2D at 0x29366d2d0>,
#   <matplotlib.lines.Line2D at 0x29366e290>,
#   <matplotlib.lines.Line2D at 0x29366e530>,
#   <matplotlib.lines.Line2D at 0x29366f4f0>,
#   <matplotlib.lines.Line2D at 0x29366f790>,
#   <matplotlib.lines.Line2D at 0x293698790>,
#   <matplotlib.lines.Line2D at 0x293698a30>],
#  'caps': [<matplotlib.lines.Line2D at 0x2935c3730>,
#   <matplotlib.lines.Line2D at 0x2935c38b0>,
#   <matplotlib.lines.Line2D at 0x2935f48b0>,
#   <matplotlib.lines.Line2D at 0x2935f4b50>,
#   <matplotlib.lines.Line2D at 0x2935f5450>,
#   <matplotlib.lines.Line2D at 0x2935f56f0>,
#   <matplotlib.lines.Line2D at 0x2935f66b0>,
#   <matplotlib.lines.Line2D at 0x2935f6950>,
#   <matplotlib.lines.Line2D at 0x2935f7910>,
#   <matplotlib.lines.Line2D at 0x2935f7bb0>,
#   <matplotlib.lines.Line2D at 0x293634bb0>,
#   <matplotlib.lines.Line2D at 0x293634e50>,
#   <matplotlib.lines.Line2D at 0x293635e10>,
#   <matplotlib.lines.Line2D at 0x2936360b0>,
#   <matplotlib.lines.Line2D at 0x293637070>,
#   <matplotlib.lines.Line2D at 0x293637310>,
#   <matplotlib.lines.Line2D at 0x29366c310>,
#   <matplotlib.lines.Line2D at 0x29366c5b0>,
#   <matplotlib.lines.Line2D at 0x29366d570>,
#   <matplotlib.lines.Line2D at 0x29366d810>,
#   <matplotlib.lines.Line2D at 0x29366e7d0>,
#   <matplotlib.lines.Line2D at 0x29366ea70>,
#   <matplotlib.lines.Line2D at 0x29366fa30>,
#   <matplotlib.lines.Line2D at 0x29366fcd0>,
#   <matplotlib.lines.Line2D at 0x293698cd0>,
#   <matplotlib.lines.Line2D at 0x293698f70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2935c2f50>,
#   <matplotlib.lines.Line2D at 0x2935f40d0>,
#   <matplotlib.lines.Line2D at 0x2935f5330>,
#   <matplotlib.lines.Line2D at 0x2935f5ed0>,
#   <matplotlib.lines.Line2D at 0x2935f7130>,
#   <matplotlib.lines.Line2D at 0x2936343d0>,
#   <matplotlib.lines.Line2D at 0x293635630>,
#   <matplotlib.lines.Line2D at 0x293636890>,
#   <matplotlib.lines.Line2D at 0x293637af0>,
#   <matplotlib.lines.Line2D at 0x29366cd90>,
#   <matplotlib.lines.Line2D at 0x29366dff0>,
#   <matplotlib.lines.Line2D at 0x29366f250>,
#   <matplotlib.lines.Line2D at 0x2936984f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2935c3b50>,
#   <matplotlib.lines.Line2D at 0x2935f4df0>,
#   <matplotlib.lines.Line2D at 0x2935f5990>,
#   <matplotlib.lines.Line2D at 0x2935f6bf0>,
#   <matplotlib.lines.Line2D at 0x2935f7e50>,
#   <matplotlib.lines.Line2D at 0x2936350f0>,
#   <matplotlib.lines.Line2D at 0x293636350>,
#   <matplotlib.lines.Line2D at 0x2936375b0>,
#   <matplotlib.lines.Line2D at 0x29366c850>,
#   <matplotlib.lines.Line2D at 0x29366dab0>,
#   <matplotlib.lines.Line2D at 0x29366ed10>,
#   <matplotlib.lines.Line2D at 0x29366ff70>,
#   <matplotlib.lines.Line2D at 0x293699210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2935c3df0>,
#   <matplotlib.lines.Line2D at 0x2935f5090>,
#   <matplotlib.lines.Line2D at 0x2935f5c30>,
#   <matplotlib.lines.Line2D at 0x2935f6e90>,
#   <matplotlib.lines.Line2D at 0x293634130>,
#   <matplotlib.lines.Line2D at 0x293635390>,
#   <matplotlib.lines.Line2D at 0x2936365f0>,
#   <matplotlib.lines.Line2D at 0x293637850>,
#   <matplotlib.lines.Line2D at 0x29366caf0>,
#   <matplotlib.lines.Line2D at 0x29366dd50>,
#   <matplotlib.lines.Line2D at 0x29366efb0>,
#   <matplotlib.lines.Line2D at 0x293698250>,
#   <matplotlib.lines.Line2D at 0x2936994b0>],
#  'means': []}

# %%
#b)
from statsmodels.graphics.mosaicplot import mosaic

#Your code:

# %% [markdown]
# ## Exercise 4
# "I am interested in the house with 3 bedrooms, 2 bathrooms and 2 floors"
# a) Compute the basic statistics of apartments fulfilling above constraints.
# b) Distinct accepted apartments on any of previously created plots.
# c) Find such apartments with best price to footage ratio.

# %%
#a)
#Your code:


#Hint: pandas.DataFrame.loc
# Out:
#                  id         price  bedrooms  bathrooms  sqft_living  \
# count  1.540000e+02  1.540000e+02     154.0      154.0   154.000000
# mean   4.397177e+09  5.144986e+05       3.0        2.0  1850.279221
# std    2.849813e+09  2.497661e+05       0.0        0.0   547.585413
# min    7.600057e+06  2.090000e+05       3.0        2.0  1020.000000
# 25%    2.060901e+09  3.769750e+05       3.0        2.0  1452.500000
# 50%    3.630010e+09  4.640000e+05       3.0        2.0  1700.000000
# 75%    7.184074e+09  5.894625e+05       3.0        2.0  2127.500000
# max    9.829200e+09  1.755000e+06       3.0        2.0  3650.000000
#
#             sqft_lot  floors  waterfront        view   condition       grade  \
# count     154.000000   154.0  154.000000  154.000000  154.000000  154.000000
# mean    23678.948052     2.0    0.006494    0.357143    3.435065    7.551948
# std     83324.024708     0.0    0.080582    0.919495    0.713322    0.832684
# min       700.000000     2.0    0.000000    0.000000    2.000000    6.000000
# 25%      3414.750000     2.0    0.000000    0.000000    3.000000    7.000000
# 50%      5868.500000     2.0    0.000000    0.000000    3.000000    7.000000
# 75%     10800.250000     2.0    0.000000    0.000000    4.000000    8.000000
# max    843309.000000     2.0    1.000000    4.000000    5.000000   10.000000
#
#         sqft_above  sqft_basement     yr_built  yr_renovated       zipcode  \
# count   154.000000     154.000000   154.000000    154.000000    154.000000
# mean   1717.422078     132.857143  1969.779221    284.863636  98085.577922
# std     527.473851     248.092631    34.654456    700.057328     48.808788
# min     720.000000       0.000000  1900.000000      0.000000  98001.000000
# 25%    1402.500000       0.000000  1942.250000      0.000000  98038.500000
# 50%    1625.000000       0.000000  1984.500000      0.000000  98103.000000
# 75%    1977.500000     207.500000  1997.500000      0.000000  98122.000000
# max    3650.000000    1120.000000  2014.000000   2014.000000  98199.000000
#
#               lat        long  sqft_living15     sqft_lot15
# count  154.000000  154.000000     154.000000     154.000000
# mean    47.567376 -122.247091    1802.337662   17545.123377
# std      0.143221    0.150507     453.210930   40404.134611
# min     47.194700 -122.519000     850.000000     886.000000
# 25%     47.498800 -122.361750    1452.500000    4020.000000
# 50%     47.584750 -122.299500    1725.000000    6278.000000
# 75%     47.682400 -122.149250    2117.500000   10392.250000
# max     47.777000 -121.709000    3170.000000  273992.000000

# %%
#b)
#Your code:

# %%
#c)
#Your code:


#Hint: .loc, .sort_values(), .index
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 9704   7452500565  20140829T000000  260000.0         3        2.0
# 11258  7937600262  20140710T000000  379900.0         3        2.0
# 19880  3832050860  20150319T000000  210000.0         3        2.0
# 16014  5104450440  20141113T000000  252500.0         3        2.0
# 20906  3355400242  20141028T000000  274900.0         3        2.0
#
#        sqft_living  sqft_lot  floors  waterfront  view     ...      grade  \
# 9704          2710      5000     2.0           0     0     ...          6
# 11258         3110     44967     2.0           0     0     ...          9
# 19880         1580      4961     2.0           0     0     ...          7
# 16014         1810     10684     2.0           0     0     ...          8
# 20906         1936      6612     2.0           0     0     ...          7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 9704         2710              0      1951             0    98126  47.5188
# 11258        3020             90      1999             0    98058  47.4343
# 19880        1580              0      2006             0    98042  47.3338
# 16014        1810              0      1987             0    98058  47.4619
# 20906        1936              0      2014             0    98001  47.2602
#
#           long  sqft_living15  sqft_lot15
# 9704  -122.373            850        5000
# 11258 -122.082           2150       44967
# 19880 -122.053           2280        5000
# 16014 -122.153           2140        9657
# 20906 -122.246           1620       21600
#
# [5 rows x 21 columns]
